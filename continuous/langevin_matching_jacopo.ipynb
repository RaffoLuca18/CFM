# %%
import jax
import jax.numpy as jnp
import optax

import matplotlib.pyplot as plt
import numpy as np

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):

    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))

    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    return samples

# %%
def potential_grad(sample, mu, cov):

    precision = jnp.linalg.inv(cov)

    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=5, seed=0):
    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples

    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise

    return evolved_samples

# %%
import time
import jax.numpy as jnp
import jax
from jax.scipy.stats import norm

def estimate_density_kde_1d(samples, grid, bandwidth):
    """Estimate KDE density on grid given samples in 1D."""
    diffs = grid[None, :] - samples[:, None]  # shape: (n_samples, n_grid)
    kernels = norm.pdf(diffs / bandwidth) / bandwidth
    density = jnp.mean(kernels, axis=0)
    return density

def compute_projected_kl(x, y, n_grid=200, bandwidth=0.1):

    seed = int(time.time() * 1e6) % (2**32)

    key = jax.random.PRNGKey(seed)
    d = x.shape[1]
    proj = jax.random.normal(key, shape=(d, 1))  # random direction
    proj /= jnp.linalg.norm(proj)  # normalize

    x_proj = x @ proj  # (n, 1)
    y_proj = y @ proj  # (m, 1)
    x_proj = x_proj.squeeze()
    y_proj = y_proj.squeeze()

    min_val = jnp.minimum(jnp.min(x_proj), jnp.min(y_proj)) - 3 * bandwidth
    max_val = jnp.maximum(jnp.max(x_proj), jnp.max(y_proj)) + 3 * bandwidth
    grid = jnp.linspace(min_val, max_val, n_grid)

    p = estimate_density_kde_1d(x_proj, grid, bandwidth)
    q = estimate_density_kde_1d(y_proj, grid, bandwidth)

    p = p / (jnp.sum(p) + 1e-8)
    q = q / (jnp.sum(q) + 1e-8)

    kl = jnp.sum(p * jnp.log((p + 1e-8) / (q + 1e-8)))

    return kl

# %%
def lm_loss(samples, mu, cov):

    evolved_samples = evolve_langevin(samples, mu, cov)

    return compute_projected_kl(samples, evolved_samples)

# %%
def lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs=1000, lr=1e-2, seed=10, eps=1e-2, plot_every=2):
    n, d = samples.shape

    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)

    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))

    params = {
        "mu": mu,
        "A": A
    }

    optimizer = optax.adam(lr)
    opt_state = optimizer.init(params)

    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)

    history = {
        "loss": [],
        "mu_l2": [],
        "cov_l2": [],
        "cov_fro": [],
    }

    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)

        # tracking
        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val

        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_l2"].append(jnp.linalg.norm(true_cov - cov_val, ord=2))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))

        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")

    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]

    return final_mu, final_cov, history

# %%
mu = jnp.array([0.0, 1.0, -1.0])

cov = jnp.array([
    [1.0, 0.5, 0.2],
    [0.5, 1.0, 0.3],
    [0.2, 0.3, 1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)

final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=800, lr=0.05, seed = 0)
# Out:
# epoch 0 | loss = 0.010041
# epoch 2 | loss = 0.008396
# epoch 4 | loss = 0.006931
# epoch 6 | loss = 0.007015
# epoch 8 | loss = 0.012353
# epoch 10 | loss = 0.012249
# epoch 12 | loss = 0.006702
# epoch 14 | loss = 0.008737
# epoch 16 | loss = 0.007468
# epoch 18 | loss = 0.008672
# epoch 20 | loss = 0.007058
# epoch 22 | loss = 0.006041
# epoch 24 | loss = 0.006551
# epoch 26 | loss = 0.006290
# epoch 28 | loss = 0.011119
# epoch 30 | loss = 0.005324
# epoch 32 | loss = 0.013480
# epoch 34 | loss = 0.008053
# epoch 36 | loss = 0.013379
# epoch 38 | loss = 0.006544
# epoch 40 | loss = 0.007043
# epoch 42 | loss = 0.005253
# epoch 44 | loss = 0.005140
# epoch 46 | loss = 0.004715
# epoch 48 | loss = 0.006476
# epoch 50 | loss = 0.012564
# epoch 52 | loss = 0.007117
# epoch 54 | loss = 0.008368
# epoch 56 | loss = 0.004870
# epoch 58 | loss = 0.009673
# epoch 60 | loss = 0.008097
# epoch 62 | loss = 0.006110
# epoch 64 | loss = 0.006097
# epoch 66 | loss = 0.007529
# epoch 68 | loss = 0.007328
# epoch 70 | loss = 0.006671
# epoch 72 | loss = 0.006087
# epoch 74 | loss = 0.011922
# epoch 76 | loss = 0.009988
# epoch 78 | loss = 0.007405
# epoch 80 | loss = 0.006188
# epoch 82 | loss = 0.004543
# epoch 84 | loss = 0.004872
# epoch 86 | loss = 0.007011
# epoch 88 | loss = 0.006628
# epoch 90 | loss = 0.005029
# epoch 92 | loss = 0.009382
# epoch 94 | loss = 0.003636
# epoch 96 | loss = 0.006032
# epoch 98 | loss = 0.013164
# epoch 100 | loss = 0.004288
# epoch 102 | loss = 0.009439
# epoch 104 | loss = 0.005894
# epoch 106 | loss = 0.004996
# epoch 108 | loss = 0.006998
# epoch 110 | loss = 0.005824
# epoch 112 | loss = 0.009209
# epoch 114 | loss = 0.012338
# epoch 116 | loss = 0.011325
# epoch 118 | loss = 0.011732
# epoch 120 | loss = 0.004760
# epoch 122 | loss = 0.008961
# epoch 124 | loss = 0.007015
# epoch 126 | loss = 0.006568
# epoch 128 | loss = 0.004000
# epoch 130 | loss = 0.011167
# epoch 132 | loss = 0.012057
# epoch 134 | loss = 0.005584
# epoch 136 | loss = 0.004410
# epoch 138 | loss = 0.007814
# epoch 140 | loss = 0.007199
# epoch 142 | loss = 0.003937
# epoch 144 | loss = 0.006052
# epoch 146 | loss = 0.005357
# epoch 148 | loss = 0.008690
# epoch 150 | loss = 0.004574
# epoch 682 | loss = 0.010792
# epoch 684 | loss = 0.005681
# epoch 686 | loss = 0.006436
# epoch 688 | loss = 0.003136
# epoch 690 | loss = 0.009706
# epoch 692 | loss = 0.009035
# epoch 694 | loss = 0.008079
# epoch 696 | loss = 0.007215
# epoch 698 | loss = 0.007768
# epoch 700 | loss = 0.006498
# epoch 702 | loss = 0.006221
# epoch 704 | loss = 0.003360
# epoch 706 | loss = 0.008056
# epoch 708 | loss = 0.005227
# epoch 710 | loss = 0.008077
# epoch 712 | loss = 0.006897
# epoch 714 | loss = 0.013730
# epoch 716 | loss = 0.007579
# epoch 718 | loss = 0.006007
# epoch 720 | loss = 0.006298
# epoch 722 | loss = 0.012143
# epoch 724 | loss = 0.002368
# epoch 726 | loss = 0.006857
# epoch 728 | loss = 0.008129
# epoch 730 | loss = 0.007159
# epoch 732 | loss = 0.007284
# epoch 734 | loss = 0.008099
# epoch 736 | loss = 0.005690
# epoch 738 | loss = 0.007254
# epoch 740 | loss = 0.007542
# epoch 742 | loss = 0.007795
# epoch 744 | loss = 0.003983
# epoch 746 | loss = 0.008500
# epoch 748 | loss = 0.006521
# epoch 750 | loss = 0.005762
# epoch 752 | loss = 0.005969
# epoch 754 | loss = 0.009852
# epoch 756 | loss = 0.006991
# epoch 758 | loss = 0.006313
# epoch 760 | loss = 0.003861
# epoch 762 | loss = 0.005496
# epoch 764 | loss = 0.011414
# epoch 766 | loss = 0.008165
# epoch 768 | loss = 0.007274
# epoch 770 | loss = 0.005843
# epoch 772 | loss = 0.008230
# epoch 774 | loss = 0.005733
# epoch 776 | loss = 0.005406
# epoch 778 | loss = 0.004677
# epoch 780 | loss = 0.002896
# epoch 782 | loss = 0.004348
# epoch 784 | loss = 0.008289
# epoch 786 | loss = 0.003246
# epoch 788 | loss = 0.007590
# epoch 790 | loss = 0.007237
# epoch 792 | loss = 0.011911
# epoch 794 | loss = 0.010109
# epoch 796 | loss = 0.005860
# epoch 798 | loss = 0.013575
# epoch 799 | loss = 0.006185

# %%
jnp.set_printoptions(precision=4, suppress=True)

print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov), "\n\n\n")
# Out:
# [ 0.  1. -1.]
#
#  [-0.6936  0.8327 -0.9648] 0.7143997
#
#
#
# [[1.  0.5 0.2]
#  [0.5 1.  0.3]
#  [0.2 0.3 1. ]]
#
#  [[4.4037 2.3014 1.6694]
#  [2.3014 2.2558 0.9689]
#  [1.6694 0.9689 2.4261]] 5.1865

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="langevin matching loss")
plt.xlabel("step")
plt.ylabel("loss")
plt.title("loss evolution")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"], label=r"$\| \mu - \hat{\mu} \|_2$")
plt.plot(history_np["cov_l2"], label=r"$\| \Sigma - \hat{\Sigma} \|_2$")
plt.plot(history_np["cov_fro"], label=r"$\| \Sigma - \hat{\Sigma} \|_F$")
plt.yscale("log")
plt.xlabel("step")
plt.title("reconstruction error")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
