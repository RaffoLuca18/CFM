# %%
import jax
import jax.numpy as jnp
import optax

import matplotlib.pyplot as plt
import numpy as np

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):

    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))

    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    return samples

# %%
def potential_grad(sample, mu, cov):

    precision = jnp.linalg.inv(cov)

    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=5, seed=0):
    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples

    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise

    return evolved_samples

# %%
import time
import jax.numpy as jnp
import jax
from jax.scipy.stats import norm

def estimate_density_kde_1d(samples, grid, bandwidth):
    """Estimate KDE density on grid given samples in 1D."""
    diffs = grid[None, :] - samples[:, None]  # shape: (n_samples, n_grid)
    kernels = norm.pdf(diffs / bandwidth) / bandwidth
    density = jnp.mean(kernels, axis=0)
    return density

def compute_projected_kl(x, y, n_grid=200, bandwidth=0.1):

    seed = int(time.time() * 1e6) % (2**32)

    key = jax.random.PRNGKey(seed)
    d = x.shape[1]
    proj = jax.random.normal(key, shape=(d, 1))  # random direction
    proj /= jnp.linalg.norm(proj)  # normalize

    x_proj = x @ proj  # (n, 1)
    y_proj = y @ proj  # (m, 1)
    x_proj = x_proj.squeeze()
    y_proj = y_proj.squeeze()

    min_val = jnp.minimum(jnp.min(x_proj), jnp.min(y_proj)) - 3 * bandwidth
    max_val = jnp.maximum(jnp.max(x_proj), jnp.max(y_proj)) + 3 * bandwidth
    grid = jnp.linspace(min_val, max_val, n_grid)

    p = estimate_density_kde_1d(x_proj, grid, bandwidth)
    q = estimate_density_kde_1d(y_proj, grid, bandwidth)

    p = p / (jnp.sum(p) + 1e-8)
    q = q / (jnp.sum(q) + 1e-8)

    kl = jnp.sum(p * jnp.log((p + 1e-8) / (q + 1e-8)))

    return kl

# %%
def lm_loss(samples, mu, cov):

    evolved_samples = evolve_langevin(samples, mu, cov)

    return compute_projected_kl(samples, evolved_samples)

# %%
def lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs=1000, lr=1e-2, seed=10, eps=1e-2, plot_every=2):
    n, d = samples.shape

    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)

    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))

    params = {
        "mu": mu,
        "A": A
    }

    optimizer = optax.adam(lr)
    opt_state = optimizer.init(params)

    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)

    history = {
        "loss": [],
        "mu_l2": [],
        "cov_l2": [],
        "cov_fro": [],
    }

    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)

        # tracking
        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val

        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_l2"].append(jnp.linalg.norm(true_cov - cov_val, ord=2))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))

        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")

    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]

    return final_mu, final_cov, history

# %%
mu = jnp.array([0.0, 1.0, -1.0])

cov = jnp.array([
    [1.0, 0.5, 0.2],
    [0.5, 1.0, 0.3],
    [0.2, 0.3, 1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)

final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=800, lr=0.05, seed = 0)
# Out:
# epoch 0 | loss = 0.011098
# epoch 2 | loss = 0.008985
# epoch 4 | loss = 0.007521
# epoch 6 | loss = 0.006971
# epoch 8 | loss = 0.006794
# epoch 10 | loss = 0.012651
# epoch 12 | loss = 0.005710
# epoch 14 | loss = 0.010789
# epoch 16 | loss = 0.011520
# epoch 18 | loss = 0.007706
# epoch 20 | loss = 0.006583
# epoch 22 | loss = 0.007518
# epoch 24 | loss = 0.007787
# epoch 26 | loss = 0.006294
# epoch 28 | loss = 0.010237
# epoch 30 | loss = 0.008325
# epoch 32 | loss = 0.007927
# epoch 34 | loss = 0.008510
# epoch 36 | loss = 0.010482
# epoch 38 | loss = 0.010406
# epoch 40 | loss = 0.006273
# epoch 42 | loss = 0.010297
# epoch 44 | loss = 0.007284
# epoch 46 | loss = 0.008821
# epoch 48 | loss = 0.003946
# epoch 50 | loss = 0.006778
# epoch 52 | loss = 0.007724
# epoch 54 | loss = 0.006818
# epoch 56 | loss = 0.010600
# epoch 58 | loss = 0.005655
# epoch 60 | loss = 0.006326
# epoch 62 | loss = 0.007043
# epoch 64 | loss = 0.006331
# epoch 66 | loss = 0.007206
# epoch 68 | loss = 0.006817
# epoch 70 | loss = 0.007349
# epoch 72 | loss = 0.009128
# epoch 74 | loss = 0.005798
# epoch 76 | loss = 0.018090
# epoch 78 | loss = 0.009077
# epoch 80 | loss = 0.007587
# epoch 82 | loss = 0.003781
# epoch 84 | loss = 0.012356
# epoch 86 | loss = 0.007853
# epoch 88 | loss = 0.004628
# epoch 90 | loss = 0.009687
# epoch 92 | loss = 0.010519
# epoch 94 | loss = 0.006452
# epoch 96 | loss = 0.007987
# epoch 98 | loss = 0.011220
# epoch 100 | loss = 0.007919
# epoch 102 | loss = 0.005262
# epoch 104 | loss = 0.006043
# epoch 106 | loss = 0.010589
# epoch 108 | loss = 0.003903
# epoch 110 | loss = 0.004294
# epoch 112 | loss = 0.009080
# epoch 114 | loss = 0.008735
# epoch 116 | loss = 0.013812
# epoch 118 | loss = 0.009614
# epoch 120 | loss = 0.007746
# epoch 122 | loss = 0.007307
# epoch 124 | loss = 0.009618
# epoch 126 | loss = 0.003992
# epoch 128 | loss = 0.011697
# epoch 130 | loss = 0.007971
# epoch 132 | loss = 0.007951
# epoch 134 | loss = 0.004995
# epoch 136 | loss = 0.005779
# epoch 138 | loss = 0.010346
# epoch 140 | loss = 0.011124
# epoch 142 | loss = 0.005791
# epoch 144 | loss = 0.009338
# epoch 146 | loss = 0.007197
# epoch 148 | loss = 0.006171
# epoch 150 | loss = 0.009220
# epoch 152 | loss = 0.006121
# epoch 154 | loss = 0.007817
# epoch 156 | loss = 0.008594
# epoch 158 | loss = 0.009732
# epoch 160 | loss = 0.011176
# epoch 162 | loss = 0.007324
# epoch 164 | loss = 0.004287
# epoch 166 | loss = 0.006977
# epoch 168 | loss = 0.006332
# epoch 170 | loss = 0.006968
# epoch 172 | loss = 0.006219
# epoch 174 | loss = 0.007137
# epoch 176 | loss = 0.007919
# epoch 178 | loss = 0.004979
# epoch 180 | loss = 0.007943
# epoch 182 | loss = 0.007267
# epoch 184 | loss = 0.002749
# epoch 186 | loss = 0.007850
# epoch 188 | loss = 0.006108
# epoch 190 | loss = 0.007321
# epoch 192 | loss = 0.006993
# epoch 194 | loss = 0.008019
# epoch 196 | loss = 0.007644
# epoch 198 | loss = 0.008291
# epoch 200 | loss = 0.010681
# epoch 202 | loss = 0.005201
# epoch 204 | loss = 0.006458
# epoch 206 | loss = 0.006759
# epoch 208 | loss = 0.007694
# epoch 210 | loss = 0.007412
# epoch 212 | loss = 0.010647
# epoch 214 | loss = 0.010766
# epoch 216 | loss = 0.007386
# epoch 218 | loss = 0.003767
# epoch 220 | loss = 0.006620
# epoch 222 | loss = 0.006489
# epoch 224 | loss = 0.005327
# epoch 226 | loss = 0.005915
# epoch 228 | loss = 0.009808
# epoch 230 | loss = 0.004875
# epoch 232 | loss = 0.007081
# epoch 234 | loss = 0.005676
# epoch 236 | loss = 0.009507
# epoch 238 | loss = 0.006948
# epoch 240 | loss = 0.006564
# epoch 242 | loss = 0.009270
# epoch 244 | loss = 0.006505
# epoch 246 | loss = 0.005670
# epoch 248 | loss = 0.004500
# epoch 250 | loss = 0.004713
# epoch 252 | loss = 0.006721
# epoch 254 | loss = 0.008514
# epoch 256 | loss = 0.002489
# epoch 258 | loss = 0.008501
# epoch 260 | loss = 0.004214
# epoch 262 | loss = 0.010567
# epoch 264 | loss = 0.009079
# epoch 266 | loss = 0.006615
# epoch 268 | loss = 0.005022
# epoch 270 | loss = 0.004898
# epoch 272 | loss = 0.009437
# epoch 274 | loss = 0.003517
# epoch 276 | loss = 0.010105
# epoch 278 | loss = 0.006593
# epoch 280 | loss = 0.005988
# epoch 282 | loss = 0.010914
# epoch 284 | loss = 0.010889
# epoch 286 | loss = 0.010634
# epoch 288 | loss = 0.005443
# epoch 290 | loss = 0.009782
# epoch 292 | loss = 0.004342
# epoch 294 | loss = 0.004881
# epoch 296 | loss = 0.009233
# epoch 298 | loss = 0.005243
# epoch 300 | loss = 0.006368
# epoch 302 | loss = 0.005351
# epoch 304 | loss = 0.007299
# epoch 306 | loss = 0.014607
# epoch 308 | loss = 0.006621
# epoch 310 | loss = 0.005084
# epoch 312 | loss = 0.008060
# epoch 314 | loss = 0.003441
# epoch 316 | loss = 0.006471
# epoch 318 | loss = 0.004923
# epoch 320 | loss = 0.007500
# epoch 322 | loss = 0.010164
# epoch 324 | loss = 0.005347
# epoch 326 | loss = 0.009577
# epoch 328 | loss = 0.005423
# epoch 330 | loss = 0.009246
# epoch 332 | loss = 0.006890
# epoch 334 | loss = 0.010238
# epoch 336 | loss = 0.006349
# epoch 338 | loss = 0.009863
# epoch 340 | loss = 0.004049
# epoch 342 | loss = 0.008744
# epoch 344 | loss = 0.007207
# epoch 346 | loss = 0.010518
# epoch 348 | loss = 0.005129
# epoch 350 | loss = 0.011597
# epoch 352 | loss = 0.007338
# epoch 354 | loss = 0.008991
# epoch 356 | loss = 0.006093
# epoch 358 | loss = 0.005634
# epoch 360 | loss = 0.008098
# epoch 362 | loss = 0.006120
# epoch 364 | loss = 0.010493
# epoch 366 | loss = 0.008329
# epoch 368 | loss = 0.006088
# epoch 370 | loss = 0.004825
# epoch 372 | loss = 0.005546
# epoch 374 | loss = 0.003385
# epoch 376 | loss = 0.012637
# epoch 378 | loss = 0.011330
# epoch 380 | loss = 0.006712
# epoch 382 | loss = 0.005661
# epoch 384 | loss = 0.008738
# epoch 386 | loss = 0.004110
# epoch 388 | loss = 0.007208
# epoch 390 | loss = 0.004833
# epoch 392 | loss = 0.008795
# epoch 394 | loss = 0.009289
# epoch 396 | loss = 0.006439
# epoch 398 | loss = 0.007519
# epoch 400 | loss = 0.006409
# epoch 402 | loss = 0.007299
# epoch 404 | loss = 0.008894
# epoch 406 | loss = 0.009485
# epoch 408 | loss = 0.004805
# epoch 410 | loss = 0.009493
# epoch 412 | loss = 0.007802
# epoch 414 | loss = 0.011503
# epoch 416 | loss = 0.010906
# epoch 418 | loss = 0.011046
# epoch 420 | loss = 0.006798
# epoch 422 | loss = 0.005141
# epoch 424 | loss = 0.012704
# epoch 426 | loss = 0.008043
# epoch 428 | loss = 0.005326
# epoch 430 | loss = 0.009192
# epoch 432 | loss = 0.014539
# epoch 434 | loss = 0.008961
# epoch 436 | loss = 0.005408
# epoch 438 | loss = 0.010788
# epoch 440 | loss = 0.010955
# epoch 442 | loss = 0.007907
# epoch 444 | loss = 0.007002
# epoch 446 | loss = 0.005800
# epoch 448 | loss = 0.007925
# epoch 450 | loss = 0.003608
# epoch 452 | loss = 0.009019
# epoch 454 | loss = 0.006458
# epoch 456 | loss = 0.006960
# epoch 458 | loss = 0.005215
# epoch 460 | loss = 0.005827
# epoch 462 | loss = 0.006795
# epoch 464 | loss = 0.008925
# epoch 466 | loss = 0.004310
# epoch 468 | loss = 0.005239
# epoch 470 | loss = 0.007445
# epoch 472 | loss = 0.007579
# epoch 474 | loss = 0.007781
# epoch 476 | loss = 0.003573
# epoch 478 | loss = 0.006386
# epoch 480 | loss = 0.006102
# epoch 482 | loss = 0.004560
# epoch 484 | loss = 0.005372
# epoch 486 | loss = 0.012055
# epoch 488 | loss = 0.002696
# epoch 490 | loss = 0.007159
# epoch 492 | loss = 0.004231
# epoch 494 | loss = 0.006759
# epoch 496 | loss = 0.006170
# epoch 498 | loss = 0.008703
# epoch 500 | loss = 0.010494
# epoch 502 | loss = 0.006953
# epoch 504 | loss = 0.010597
# epoch 506 | loss = 0.006016
# epoch 508 | loss = 0.004317
# epoch 510 | loss = 0.008070
# epoch 512 | loss = 0.009850
# epoch 514 | loss = 0.006090
# epoch 516 | loss = 0.009384
# epoch 518 | loss = 0.006137
# epoch 520 | loss = 0.007999
# epoch 522 | loss = 0.005104
# epoch 524 | loss = 0.008788
# epoch 526 | loss = 0.009529
# epoch 528 | loss = 0.003634
# epoch 530 | loss = 0.009788
# epoch 532 | loss = 0.010862
# epoch 534 | loss = 0.006435
# epoch 536 | loss = 0.007675
# epoch 538 | loss = 0.009443
# epoch 540 | loss = 0.006055
# epoch 542 | loss = 0.003828
# epoch 544 | loss = 0.008322
# epoch 546 | loss = 0.005502
# epoch 548 | loss = 0.008041
# epoch 550 | loss = 0.007687
# epoch 552 | loss = 0.005114
# epoch 554 | loss = 0.003004
# epoch 556 | loss = 0.006925
# epoch 558 | loss = 0.005344
# epoch 560 | loss = 0.011124
# epoch 562 | loss = 0.007528
# epoch 564 | loss = 0.010113
# epoch 566 | loss = 0.005008
# epoch 568 | loss = 0.005036
# epoch 570 | loss = 0.006417
# epoch 572 | loss = 0.008915
# epoch 574 | loss = 0.008039
# epoch 576 | loss = 0.011251
# epoch 578 | loss = 0.013510
# epoch 580 | loss = 0.004250
# epoch 582 | loss = 0.004687
# epoch 584 | loss = 0.005190
# epoch 586 | loss = 0.003773
# epoch 588 | loss = 0.006264
# epoch 590 | loss = 0.005901
# epoch 592 | loss = 0.005822
# epoch 594 | loss = 0.004170
# epoch 596 | loss = 0.006931
# epoch 598 | loss = 0.009826
# epoch 600 | loss = 0.005446
# epoch 602 | loss = 0.003196
# epoch 604 | loss = 0.007588
# epoch 606 | loss = 0.008815
# epoch 608 | loss = 0.006950
# epoch 610 | loss = 0.003245
# epoch 612 | loss = 0.005499
# epoch 614 | loss = 0.008405
# epoch 616 | loss = 0.007756
# epoch 618 | loss = 0.009202
# epoch 620 | loss = 0.006156
# epoch 622 | loss = 0.010892
# epoch 624 | loss = 0.007541
# epoch 626 | loss = 0.005686
# epoch 628 | loss = 0.007787
# epoch 630 | loss = 0.009302
# epoch 632 | loss = 0.007938
# epoch 634 | loss = 0.006045
# epoch 636 | loss = 0.006284
# epoch 638 | loss = 0.004605
# epoch 640 | loss = 0.003347
# epoch 642 | loss = 0.006349
# epoch 644 | loss = 0.004585
# epoch 646 | loss = 0.004147
# epoch 648 | loss = 0.009040
# epoch 650 | loss = 0.010937
# epoch 652 | loss = 0.010396
# epoch 654 | loss = 0.010843
# epoch 656 | loss = 0.004236
# epoch 658 | loss = 0.006025
# epoch 660 | loss = 0.007631
# epoch 662 | loss = 0.005944
# epoch 664 | loss = 0.008452
# epoch 666 | loss = 0.006776
# epoch 668 | loss = 0.004414
# epoch 670 | loss = 0.008916
# epoch 672 | loss = 0.005510
# epoch 674 | loss = 0.004818
# epoch 676 | loss = 0.007487
# epoch 678 | loss = 0.006265
# epoch 680 | loss = 0.004843
# epoch 682 | loss = 0.005506
# epoch 684 | loss = 0.006696
# epoch 686 | loss = 0.008002
# epoch 688 | loss = 0.012174
# epoch 690 | loss = 0.006975
# epoch 692 | loss = 0.013658
# epoch 694 | loss = 0.009021
# epoch 696 | loss = 0.010030
# epoch 698 | loss = 0.007265
# epoch 700 | loss = 0.013052
# epoch 702 | loss = 0.005863
# epoch 704 | loss = 0.008646
# epoch 706 | loss = 0.008334
# epoch 708 | loss = 0.006947
# epoch 710 | loss = 0.008463
# epoch 712 | loss = 0.007501
# epoch 714 | loss = 0.007691
# epoch 716 | loss = 0.007991
# epoch 718 | loss = 0.006098
# epoch 720 | loss = 0.007155
# epoch 722 | loss = 0.007705
# epoch 724 | loss = 0.005778
# epoch 726 | loss = 0.007664
# epoch 728 | loss = 0.005315
# epoch 730 | loss = 0.009859
# epoch 732 | loss = 0.004895
# epoch 734 | loss = 0.008444
# epoch 736 | loss = 0.009409
# epoch 738 | loss = 0.004754
# epoch 740 | loss = 0.007034
# epoch 742 | loss = 0.007732
# epoch 744 | loss = 0.006605
# epoch 746 | loss = 0.011534
# epoch 748 | loss = 0.005226
# epoch 750 | loss = 0.005170
# epoch 752 | loss = 0.005991
# epoch 754 | loss = 0.007979
# epoch 756 | loss = 0.004059
# epoch 758 | loss = 0.008141
# epoch 760 | loss = 0.008125
# epoch 762 | loss = 0.005867
# epoch 764 | loss = 0.010326
# epoch 766 | loss = 0.004661
# epoch 768 | loss = 0.006572
# epoch 770 | loss = 0.006385
# epoch 772 | loss = 0.005998
# epoch 774 | loss = 0.008256
# epoch 776 | loss = 0.010244
# epoch 778 | loss = 0.005354
# epoch 780 | loss = 0.014099
# epoch 782 | loss = 0.008174
# epoch 784 | loss = 0.006110
# epoch 786 | loss = 0.008701
# epoch 788 | loss = 0.010136
# epoch 790 | loss = 0.005068
# epoch 792 | loss = 0.007562
# epoch 794 | loss = 0.007868
# epoch 796 | loss = 0.005002
# epoch 798 | loss = 0.005162
# epoch 799 | loss = 0.008823

# %%
jnp.set_printoptions(precision=4, suppress=True)

print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov), "\n\n\n")
# Out:
# [ 0.  1. -1.]
#
#  [-0.6337  0.5786 -1.0643] 0.76369154
#
#
#
# [[1.  0.5 0.2]
#  [0.5 1.  0.3]
#  [0.2 0.3 1. ]]
#
#  [[4.9104 2.6619 2.1859]
#  [2.6619 2.5354 1.4553]
#  [2.1859 1.4553 1.9616]] 6.203073

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="langevin matching loss")
plt.xlabel("step")
plt.ylabel("loss")
plt.title("loss evolution")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"], label=r"$\| \mu - \hat{\mu} \|_2$")
plt.plot(history_np["cov_l2"], label=r"$\| \Sigma - \hat{\Sigma} \|_2$")
plt.plot(history_np["cov_fro"], label=r"$\| \Sigma - \hat{\Sigma} \|_F$")
plt.yscale("log")
plt.xlabel("step")
plt.title("reconstruction error")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
