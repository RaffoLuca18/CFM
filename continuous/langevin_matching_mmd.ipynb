# %%
import jax
import jax.numpy as jnp
import optax

import matplotlib.pyplot as plt
import numpy as np

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):

    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))

    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    return samples

# %%
def potential_grad(sample, mu, cov):

    precision = jnp.linalg.inv(cov)

    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=5, seed=0):
    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples

    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise

    return evolved_samples

# %%
def rbf_kernel(x, y, sigma=1.0):
    """Compute RBF kernel matrix between x and y."""
    x_norm = jnp.sum(x**2, axis=1, keepdims=True)
    y_norm = jnp.sum(y**2, axis=1, keepdims=True)
    dists = x_norm - 2 * x @ y.T + y_norm.T
    return jnp.exp(-dists / (2 * sigma**2))

def compute_mmd_distance(x, y, sigma=1.0):
    """
    Compute unbiased estimate of MMD^2 between two empirical distributions.
    """
    n = x.shape[0]
    m = y.shape[0]

    k_xx = rbf_kernel(x, x, sigma)
    k_yy = rbf_kernel(y, y, sigma)
    k_xy = rbf_kernel(x, y, sigma)

    # unbiased estimate
    mmd = (
        (jnp.sum(k_xx) - jnp.trace(k_xx)) / (n * (n - 1)) +
        (jnp.sum(k_yy) - jnp.trace(k_yy)) / (m * (m - 1)) -
        2 * jnp.sum(k_xy) / (n * m)
    )
    return mmd

# %%
def lm_loss(samples, mu, cov):

    evolved_samples = evolve_langevin(samples, mu, cov)

    return compute_mmd_distance(samples, evolved_samples)

# %%
def lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs=1000, lr=1e-2, seed=10, eps=1e-2, plot_every=2):
    n, d = samples.shape

    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)

    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))

    params = {
        "mu": mu,
        "A": A
    }

    optimizer = optax.adam(lr)
    opt_state = optimizer.init(params)

    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)

    history = {
        "loss": [],
        "mu_l2": [],
        "cov_l2": [],
        "cov_fro": [],
    }

    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)

        # tracking
        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val

        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_l2"].append(jnp.linalg.norm(true_cov - cov_val, ord=2))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))

        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")

    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]

    return final_mu, final_cov, history

# %%
mu = jnp.array([0.0, 1.0, -1.0])

cov = jnp.array([
    [1.0, 0.5, 0.2],
    [0.5, 1.0, 0.3],
    [0.2, 0.3, 1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)

final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=800, lr=0.05, seed = 0)
# Out:
# epoch 0 | loss = 0.000971
# epoch 2 | loss = 0.000095
# epoch 4 | loss = -0.000136
# epoch 6 | loss = -0.000218
# epoch 8 | loss = -0.000257
# epoch 10 | loss = -0.000280
# epoch 12 | loss = -0.000299
# epoch 14 | loss = -0.000317
# epoch 16 | loss = -0.000335
# epoch 18 | loss = -0.000353
# epoch 20 | loss = -0.000370
# epoch 22 | loss = -0.000384
# epoch 24 | loss = -0.000401
# epoch 26 | loss = -0.000425
# epoch 28 | loss = -0.000452
# epoch 30 | loss = -0.000470
# epoch 32 | loss = -0.000477
# epoch 34 | loss = -0.000474
# epoch 36 | loss = -0.000468
# epoch 38 | loss = -0.000467
# epoch 40 | loss = -0.000472
# epoch 42 | loss = -0.000479
# epoch 44 | loss = -0.000486
# epoch 46 | loss = -0.000490
# epoch 48 | loss = -0.000492
# epoch 50 | loss = -0.000492
# epoch 52 | loss = -0.000493
# epoch 54 | loss = -0.000496
# epoch 56 | loss = -0.000499
# epoch 58 | loss = -0.000502
# epoch 60 | loss = -0.000505
# epoch 62 | loss = -0.000508
# epoch 64 | loss = -0.000510
# epoch 66 | loss = -0.000512
# epoch 68 | loss = -0.000515
# epoch 70 | loss = -0.000517
# epoch 72 | loss = -0.000520
# epoch 74 | loss = -0.000523
# epoch 76 | loss = -0.000526
# epoch 78 | loss = -0.000528
# epoch 80 | loss = -0.000531
# epoch 82 | loss = -0.000534
# epoch 84 | loss = -0.000537
# epoch 86 | loss = -0.000540
# epoch 88 | loss = -0.000544
# epoch 90 | loss = -0.000547
# epoch 92 | loss = -0.000550
# epoch 94 | loss = -0.000554
# epoch 96 | loss = -0.000557
# epoch 98 | loss = -0.000561
# epoch 100 | loss = -0.000565
# epoch 102 | loss = -0.000569
# epoch 104 | loss = -0.000573
# epoch 106 | loss = -0.000577
# epoch 108 | loss = -0.000581
# epoch 110 | loss = -0.000586
# epoch 112 | loss = -0.000590
# epoch 114 | loss = -0.000595
# epoch 116 | loss = -0.000600
# epoch 118 | loss = -0.000605
# epoch 120 | loss = -0.000609
# epoch 122 | loss = -0.000614
# epoch 124 | loss = -0.000619
# epoch 126 | loss = -0.000623
# epoch 128 | loss = -0.000627
# epoch 130 | loss = -0.000631
# epoch 132 | loss = -0.000634
# epoch 134 | loss = -0.000637
# epoch 136 | loss = -0.000639
# epoch 138 | loss = -0.000641
# epoch 140 | loss = -0.000643
# epoch 142 | loss = -0.000644
# epoch 144 | loss = -0.000646
# epoch 146 | loss = -0.000647
# epoch 148 | loss = -0.000649
# epoch 150 | loss = -0.000651
# epoch 152 | loss = -0.000652
# epoch 154 | loss = -0.000654
# epoch 156 | loss = -0.000656
# epoch 158 | loss = -0.000657
# epoch 160 | loss = -0.000659
# epoch 162 | loss = -0.000660
# epoch 164 | loss = -0.000662
# epoch 166 | loss = -0.000664
# epoch 168 | loss = -0.000666
# epoch 170 | loss = -0.000668
# epoch 172 | loss = -0.000671
# epoch 174 | loss = -0.000673
# epoch 176 | loss = -0.000676
# epoch 178 | loss = -0.000679
# epoch 180 | loss = -0.000682
# epoch 182 | loss = -0.000686
# epoch 184 | loss = -0.000689
# epoch 186 | loss = -0.000694
# epoch 188 | loss = -0.000698
# epoch 190 | loss = -0.000703
# epoch 192 | loss = -0.000707
# epoch 194 | loss = -0.000712
# epoch 196 | loss = -0.000715
# epoch 198 | loss = -0.000719
# epoch 200 | loss = -0.000720
# epoch 202 | loss = -0.000722
# epoch 204 | loss = -0.000722
# epoch 206 | loss = -0.000722
# epoch 208 | loss = -0.000723
# epoch 210 | loss = -0.000723
# epoch 212 | loss = -0.000724
# epoch 214 | loss = -0.000725
# epoch 216 | loss = -0.000726
# epoch 218 | loss = -0.000726
# epoch 220 | loss = -0.000726
# epoch 222 | loss = -0.000727
# epoch 224 | loss = -0.000727
# epoch 226 | loss = -0.000727
# epoch 228 | loss = -0.000727
# epoch 230 | loss = -0.000727
# epoch 232 | loss = -0.000727
# epoch 234 | loss = -0.000727
# epoch 236 | loss = -0.000727
# epoch 238 | loss = -0.000727
# epoch 240 | loss = -0.000727
# epoch 242 | loss = -0.000727
# epoch 244 | loss = -0.000727
# epoch 246 | loss = -0.000727
# epoch 248 | loss = -0.000727
# epoch 250 | loss = -0.000727
# epoch 252 | loss = -0.000727
# epoch 254 | loss = -0.000727
# epoch 256 | loss = -0.000727
# epoch 258 | loss = -0.000727
# epoch 260 | loss = -0.000727
# epoch 262 | loss = -0.000727
# epoch 264 | loss = -0.000727
# epoch 266 | loss = -0.000727
# epoch 268 | loss = -0.000727
# epoch 270 | loss = -0.000727
# epoch 272 | loss = -0.000727
# epoch 274 | loss = -0.000727
# epoch 276 | loss = -0.000727
# epoch 278 | loss = -0.000727
# epoch 280 | loss = -0.000727
# epoch 282 | loss = -0.000727
# epoch 284 | loss = -0.000727
# epoch 286 | loss = -0.000727
# epoch 288 | loss = -0.000727
# epoch 290 | loss = -0.000727
# epoch 292 | loss = -0.000727
# epoch 294 | loss = -0.000727
# epoch 296 | loss = -0.000727
# epoch 298 | loss = -0.000727
# epoch 300 | loss = -0.000727
# epoch 302 | loss = -0.000727
# epoch 304 | loss = -0.000727
# epoch 306 | loss = -0.000727
# epoch 308 | loss = -0.000727
# epoch 310 | loss = -0.000727
# epoch 312 | loss = -0.000727
# epoch 314 | loss = -0.000727
# epoch 316 | loss = -0.000727
# epoch 318 | loss = -0.000727
# epoch 320 | loss = -0.000727
# epoch 322 | loss = -0.000727
# epoch 324 | loss = -0.000727
# epoch 326 | loss = -0.000727
# epoch 328 | loss = -0.000727
# epoch 330 | loss = -0.000727
# epoch 332 | loss = -0.000727
# epoch 334 | loss = -0.000727
# epoch 336 | loss = -0.000727
# epoch 338 | loss = -0.000727
# epoch 340 | loss = -0.000727
# epoch 342 | loss = -0.000727
# epoch 344 | loss = -0.000727
# epoch 346 | loss = -0.000727
# epoch 348 | loss = -0.000727
# epoch 350 | loss = -0.000727
# epoch 352 | loss = -0.000727
# epoch 354 | loss = -0.000727
# epoch 356 | loss = -0.000727
# epoch 358 | loss = -0.000727
# epoch 360 | loss = -0.000727
# epoch 362 | loss = -0.000727
# epoch 364 | loss = -0.000727
# epoch 366 | loss = -0.000727
# epoch 368 | loss = -0.000727
# epoch 370 | loss = -0.000727
# epoch 372 | loss = -0.000727
# epoch 374 | loss = -0.000727
# epoch 376 | loss = -0.000727
# epoch 378 | loss = -0.000727
# epoch 380 | loss = -0.000727
# epoch 382 | loss = -0.000727
# epoch 384 | loss = -0.000727
# epoch 386 | loss = -0.000727
# epoch 388 | loss = -0.000727
# epoch 390 | loss = -0.000727
# epoch 392 | loss = -0.000727
# epoch 394 | loss = -0.000727
# epoch 396 | loss = -0.000727
# epoch 398 | loss = -0.000727
# epoch 400 | loss = -0.000727
# epoch 402 | loss = -0.000727
# epoch 404 | loss = -0.000727
# epoch 406 | loss = -0.000727
# epoch 408 | loss = -0.000727
# epoch 410 | loss = -0.000727
# epoch 412 | loss = -0.000727
# epoch 414 | loss = -0.000727
# epoch 416 | loss = -0.000727
# epoch 418 | loss = -0.000727
# epoch 420 | loss = -0.000727
# epoch 422 | loss = -0.000727
# epoch 424 | loss = -0.000727
# epoch 426 | loss = -0.000727
# epoch 428 | loss = -0.000727
# epoch 430 | loss = -0.000727
# epoch 432 | loss = -0.000727
# epoch 434 | loss = -0.000727
# epoch 436 | loss = -0.000727
# epoch 438 | loss = -0.000727
# epoch 440 | loss = -0.000727
# epoch 442 | loss = -0.000727
# epoch 444 | loss = -0.000727
# epoch 446 | loss = -0.000727
# epoch 448 | loss = -0.000727
# epoch 450 | loss = -0.000727
# epoch 452 | loss = -0.000727
# epoch 454 | loss = -0.000727
# epoch 456 | loss = -0.000727
# epoch 458 | loss = -0.000727
# epoch 460 | loss = -0.000727
# epoch 462 | loss = -0.000727
# epoch 464 | loss = -0.000727
# epoch 466 | loss = -0.000727
# epoch 468 | loss = -0.000727
# epoch 470 | loss = -0.000727
# epoch 472 | loss = -0.000727
# epoch 474 | loss = -0.000727
# epoch 476 | loss = -0.000727
# epoch 478 | loss = -0.000727
# epoch 480 | loss = -0.000727
# epoch 482 | loss = -0.000727
# epoch 484 | loss = -0.000727
# epoch 486 | loss = -0.000727
# epoch 488 | loss = -0.000727
# epoch 490 | loss = -0.000727
# epoch 492 | loss = -0.000727
# epoch 494 | loss = -0.000727
# epoch 496 | loss = -0.000727
# epoch 498 | loss = -0.000727
# epoch 500 | loss = -0.000727
# epoch 502 | loss = -0.000727
# epoch 504 | loss = -0.000727
# epoch 506 | loss = -0.000727
# epoch 508 | loss = -0.000727
# epoch 510 | loss = -0.000727
# epoch 512 | loss = -0.000727
# epoch 514 | loss = -0.000727
# epoch 516 | loss = -0.000727
# epoch 518 | loss = -0.000727
# epoch 520 | loss = -0.000727
# epoch 522 | loss = -0.000727
# epoch 524 | loss = -0.000727
# epoch 526 | loss = -0.000727
# epoch 528 | loss = -0.000727
# epoch 530 | loss = -0.000727
# epoch 532 | loss = -0.000727
# epoch 534 | loss = -0.000727
# epoch 536 | loss = -0.000727
# epoch 538 | loss = -0.000727
# epoch 540 | loss = -0.000727
# epoch 542 | loss = -0.000727
# epoch 544 | loss = -0.000727
# epoch 546 | loss = -0.000727
# epoch 548 | loss = -0.000727
# epoch 550 | loss = -0.000727
# epoch 552 | loss = -0.000727
# epoch 554 | loss = -0.000727
# epoch 556 | loss = -0.000727
# epoch 558 | loss = -0.000727
# epoch 560 | loss = -0.000727
# epoch 562 | loss = -0.000727
# epoch 564 | loss = -0.000727
# epoch 566 | loss = -0.000727
# epoch 568 | loss = -0.000727
# epoch 570 | loss = -0.000727
# epoch 572 | loss = -0.000727
# epoch 574 | loss = -0.000727
# epoch 576 | loss = -0.000727
# epoch 578 | loss = -0.000727
# epoch 580 | loss = -0.000727
# epoch 582 | loss = -0.000727
# epoch 584 | loss = -0.000727
# epoch 586 | loss = -0.000727
# epoch 588 | loss = -0.000727
# epoch 590 | loss = -0.000727
# epoch 592 | loss = -0.000727
# epoch 594 | loss = -0.000727
# epoch 596 | loss = -0.000727
# epoch 598 | loss = -0.000727
# epoch 600 | loss = -0.000727
# epoch 602 | loss = -0.000727
# epoch 604 | loss = -0.000727
# epoch 606 | loss = -0.000727
# epoch 608 | loss = -0.000727
# epoch 610 | loss = -0.000727
# epoch 612 | loss = -0.000727
# epoch 614 | loss = -0.000727
# epoch 616 | loss = -0.000727
# epoch 618 | loss = -0.000727
# epoch 620 | loss = -0.000727
# epoch 622 | loss = -0.000727
# epoch 624 | loss = -0.000727
# epoch 626 | loss = -0.000727
# epoch 628 | loss = -0.000727
# epoch 630 | loss = -0.000727
# epoch 632 | loss = -0.000727
# epoch 634 | loss = -0.000727
# epoch 636 | loss = -0.000727
# epoch 638 | loss = -0.000727
# epoch 640 | loss = -0.000727
# epoch 642 | loss = -0.000727
# epoch 644 | loss = -0.000727
# epoch 646 | loss = -0.000727
# epoch 648 | loss = -0.000727
# epoch 650 | loss = -0.000727
# epoch 652 | loss = -0.000727
# epoch 654 | loss = -0.000727
# epoch 656 | loss = -0.000727
# epoch 658 | loss = -0.000727
# epoch 660 | loss = -0.000727
# epoch 662 | loss = -0.000727
# epoch 664 | loss = -0.000727
# epoch 666 | loss = -0.000727
# epoch 668 | loss = -0.000727
# epoch 670 | loss = -0.000727
# epoch 672 | loss = -0.000727
# epoch 674 | loss = -0.000727
# epoch 676 | loss = -0.000727
# epoch 678 | loss = -0.000727
# epoch 680 | loss = -0.000727
# epoch 682 | loss = -0.000727
# epoch 684 | loss = -0.000727
# epoch 686 | loss = -0.000727
# epoch 688 | loss = -0.000727
# epoch 690 | loss = -0.000727
# epoch 692 | loss = -0.000727
# epoch 694 | loss = -0.000727
# epoch 696 | loss = -0.000727
# epoch 698 | loss = -0.000727
# epoch 700 | loss = -0.000727
# epoch 702 | loss = -0.000727
# epoch 704 | loss = -0.000727
# epoch 706 | loss = -0.000727
# epoch 708 | loss = -0.000727
# epoch 710 | loss = -0.000727
# epoch 712 | loss = -0.000727
# epoch 714 | loss = -0.000727
# epoch 716 | loss = -0.000727
# epoch 718 | loss = -0.000727
# epoch 720 | loss = -0.000727
# epoch 722 | loss = -0.000727
# epoch 724 | loss = -0.000727
# epoch 726 | loss = -0.000727
# epoch 728 | loss = -0.000727
# epoch 730 | loss = -0.000727
# epoch 732 | loss = -0.000727
# epoch 734 | loss = -0.000727
# epoch 736 | loss = -0.000727
# epoch 738 | loss = -0.000727
# epoch 740 | loss = -0.000727
# epoch 742 | loss = -0.000727
# epoch 744 | loss = -0.000727
# epoch 746 | loss = -0.000727
# epoch 748 | loss = -0.000727
# epoch 750 | loss = -0.000727
# epoch 752 | loss = -0.000727
# epoch 754 | loss = -0.000727
# epoch 756 | loss = -0.000727
# epoch 758 | loss = -0.000727
# epoch 760 | loss = -0.000727
# epoch 762 | loss = -0.000727
# epoch 764 | loss = -0.000727
# epoch 766 | loss = -0.000727
# epoch 768 | loss = -0.000727
# epoch 770 | loss = -0.000727
# epoch 772 | loss = -0.000727
# epoch 774 | loss = -0.000727
# epoch 776 | loss = -0.000727
# epoch 778 | loss = -0.000727
# epoch 780 | loss = -0.000727
# epoch 782 | loss = -0.000727
# epoch 784 | loss = -0.000727
# epoch 786 | loss = -0.000727
# epoch 788 | loss = -0.000727
# epoch 790 | loss = -0.000727
# epoch 792 | loss = -0.000727
# epoch 794 | loss = -0.000727
# epoch 796 | loss = -0.000727
# epoch 798 | loss = -0.000727
# epoch 799 | loss = -0.000727

# %%
jnp.set_printoptions(precision=4, suppress=True)

print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov), "\n\n\n")
# Out:
# [ 0.  1. -1.]
#
#  [ 0.314   1.3836 -0.4919] 0.7098605
#
#
#
# [[1.  0.5 0.2]
#  [0.5 1.  0.3]
#  [0.2 0.3 1. ]]
#
#  [[1.0491 0.5606 0.3582]
#  [0.5606 1.1761 0.295 ]
#  [0.3582 0.295  1.317 ]] 0.43742537

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="langevin matching loss")
plt.xlabel("step")
plt.ylabel("loss")
plt.title("loss evolution")
plt.grid(True)
plt.legend()

ymin_recon = 1e-2
ymax_recon = 100.0
plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"], label=r"$\| \mu - \hat{\mu} \|_2$")
plt.plot(history_np["cov_l2"], label=r"$\| \Sigma - \hat{\Sigma} \|_2$")
plt.plot(history_np["cov_fro"], label=r"$\| \Sigma - \hat{\Sigma} \|_F$")
plt.ylim(ymin_recon, ymax_recon)
plt.yscale("log")
plt.xlabel("step")
plt.title("reconstruction error")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
