# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import data_gen as dg
import ising as isg

import jax
import jax.numpy as jnp
import optax

# %%
def langevin_step(sample, theta, eps, key):
    
    noise = jax.random.normal(key, shape=sample.shape)
    grad_V = sample - theta

    return sample - eps * grad_V + jnp.sqrt(2 * eps) * noise

# %%
def evolve_langevin(samples, theta, counter, eps=1e-2, n_evolution=1, seed=0):
    
    key = jax.random.PRNGKey(seed + counter)
    samples_evolved = samples

    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        samples_evolved = langevin_step(samples_evolved, theta, eps, subkey)

    return samples_evolved

# %%
from ott.tools import sinkhorn_divergence

def lm_loss(samples, theta, counter):

    samples = samples[:, None]

    evolved_samples = evolve_langevin(samples, theta, counter)

    loss = sinkhorn_divergence.sinkdiv(samples, evolved_samples)[0]

    return loss

# %%
def lm_optimize(samples, n_epochs=300, lr=1e-2):

    theta = jnp.array(0.0)

    optimizer = optax.adam(lr)
    opt_state = optimizer.init(theta)
    counter = 0

    def loss_fn(theta):
        return lm_loss(samples, theta, counter)

    for t in range(n_epochs):
        loss_val, grad = jax.value_and_grad(loss_fn)(theta)
        updates, opt_state = optimizer.update(grad, opt_state)
        theta = optax.apply_updates(theta, updates)
        counter += 1

        if t % 5 == 0:
            print(f"step {t} | loss = {loss_val:.6f} | theta = {theta:.4f}")

    return theta

# %%
true_theta = 10.0
key = jax.random.PRNGKey(0)

samples = jax.random.normal(key, shape=(500,)) + true_theta

theta_hat = lm_optimize(samples, n_epochs=3000, lr=0.5)

print(f"\nfinal theta: {theta_hat:.4f}")
# Out:
# 0
# step 0 | loss = 0.013957 | theta = 0.5000
# 1
# 2
# 3
# 4
# 5
# step 5 | loss = 0.006663 | theta = 2.9385
# 6
# 7
# 8
# 9
# 10
# step 10 | loss = 0.002856 | theta = 5.2465
# 11
# 12
# 13
# 14
# 15
# step 15 | loss = 0.001306 | theta = 7.3427
# 16
# 17
# 18
# 19
# 20
# step 20 | loss = 0.000684 | theta = 9.0574
# 21
# 22
# 23
# 24
# 25
# step 25 | loss = 0.000574 | theta = 10.2947
# 26
# 27
# 28
# 29
# 30
# step 30 | loss = 0.000402 | theta = 11.0322
# 31
# 32
# 33
# 34
# 35
# step 35 | loss = 0.000887 | theta = 11.3354
# 36
# 37
# 38
# 39
# 40
# step 40 | loss = 0.001094 | theta = 11.2074
# 41
# 42
# 43
# 44
# 45
# step 45 | loss = 0.000726 | theta = 10.8241
# 46
# 47
# 48
# 49
# 50
# step 50 | loss = 0.000413 | theta = 10.3558
# 51
# 52
# 53
# 54
# 55
# step 55 | loss = 0.000311 | theta = 10.0120
# 56
# 57
# 58
# 59
# 60
# step 60 | loss = 0.000847 | theta = 9.8248
# 61
# 62
# 63
# 64
# 65
# step 65 | loss = 0.001411 | theta = 9.7615
# 66
# 67
# 68
# 69
# 70
# step 70 | loss = 0.000458 | theta = 9.9274
# 71
# 72
# 73
# 74
# 75
# step 75 | loss = 0.000398 | theta = 10.0421
# 76
# 77
# 78
# 79
# 80
# step 80 | loss = 0.000311 | theta = 10.0433
# 81
# 82
# 83
# 84
# 85
# step 85 | loss = 0.000354 | theta = 10.0238
# 86
# 87
# 88
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 6
#       2 key = jax.random.PRNGKey(0)
#       4 samples = jax.random.normal(key, shape=(500,)) + true_theta
# ----> 6 theta_hat = lm_optimize(samples, n_epochs=3000, lr=0.5)
#       8 print(f"\nfinal theta: {theta_hat:.4f}")
#
# Cell In[76], line 13, in lm_optimize(samples, n_epochs, lr)
#      10     return lm_loss(samples, theta, counter)
#      12 for t in range(n_epochs):
# ---> 13     loss_val, grad = jax.value_and_grad(loss_fn)(theta)
#      14     updates, opt_state = optimizer.update(grad, opt_state)
#      15     theta = optax.apply_updates(theta, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/api.py:510, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     508   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     509 if not has_aux:
# --> 510   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     511 else:
#     512   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/api.py:2179, in _vjp(fun, has_aux, *primals)
#    2177 if not has_aux:
#    2178   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2179   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2180   out_tree = out_tree()
#    2181 else:
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:292, in vjp(traceable, primals, has_aux)
#     290 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     291   if not has_aux:
# --> 292     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     293   else:
#     294     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:277, in linearize(traceable, *primals, **kwargs)
#     275 _, in_tree = tree_flatten(((primals, primals), {}))
#     276 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 277 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     278 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     279 if any(not out_primal_pval.is_known() for out_primal_pval in out_primals_pvals):
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:614, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     612 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate, fun.debug_info)
#     613 with core.set_current_trace(trace):
# --> 614   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     615   assert not env
#     616 del trace, fun
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:628, in trace_to_subjaxpr_nounits(f, trace, instantiate, debug_info, in_pvals)
#     620 @lu.transformation2
#     621 def trace_to_subjaxpr_nounits(
#     622     f: Callable,
#    (...)    625     debug_info: core.DebugInfo,
#     626     in_pvals: Sequence[PartialVal]):
#     627   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 628   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     629       f, trace, instantiate, in_pvals, debug_info)
#     630   out_pvals = [t.pval for t in out_tracers]
#     631   del out_tracers
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:661, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     659 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     660 with core.set_current_trace(trace):
# --> 661   ans = f(*in_args)
#     662 assert isinstance(ans, (list, tuple)), (
#     663     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     664 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     665     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:81, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      78 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      79        else contextlib.nullcontext())
#      80 with ctx:
# ---> 81   out_primals, out_tangents = f(tag, primals, tangents)
#      82 if type(instantiate) is bool:
#      83   instantiate = [instantiate] * len(out_tangents)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:136, in jvp_subtrace(f, tag, primals, tangents)
#     133   in_tracers = [maybe_jvp_tracer(trace, x, t)
#     134                 for x, t in zip(primals, tangents)]
#     135   with core.set_current_trace(trace):
# --> 136     ans = f(*in_tracers)
#     137   out = unzip2(map(trace.to_primal_tangent_pair, ans))
#     138 return out
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# Cell In[76], line 10, in lm_optimize.<locals>.loss_fn(theta)
#       9 def loss_fn(theta):
# ---> 10     return lm_loss(samples, theta, counter)
#
# Cell In[75], line 9, in lm_loss(samples, theta, counter)
#       5 samples = samples[:, None]
#       7 evolved_samples = evolve_langevin(samples, theta, counter)
# ----> 9 loss = sinkhorn_divergence.sinkdiv(samples, evolved_samples)[0]
#      11 return loss
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/tools/sinkhorn_divergence.py:146, in sinkdiv(x, y, cost_fn, epsilon, **kwargs)
#     114 def sinkdiv(
#     115     x: jnp.ndarray,
#     116     y: jnp.ndarray,
#    (...)    120     **kwargs: Any,
#     121 ) -> Tuple[jnp.ndarray, SinkhornDivergenceOutput]:
#     122   """Wrapper to get the :term:`Sinkhorn divergence` between two point clouds.
#     123
#     124   Convenience wrapper around
#    (...)    144     The Sinkhorn divergence value, and output object detailing computations.
#     145   """
# --> 146   return sinkhorn_divergence(
#     147       pointcloud.PointCloud,
#     148       x=x,
#     149       y=y,
#     150       cost_fn=cost_fn,
#     151       epsilon=epsilon,
#     152       **kwargs
#     153   )
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/tools/sinkhorn_divergence.py:223, in sinkhorn_divergence(geom, a, b, solve_kwargs, static_b, offset_static_b, share_epsilon, symmetric_sinkhorn, *args, **kwargs)
#     221 a = jnp.ones(num_a) / num_a if a is None else a
#     222 b = jnp.ones(num_b) / num_b if b is None else b
# --> 223 out = _sinkhorn_divergence(
#     224     geom_xy,
#     225     geom_x,
#     226     geom_y,
#     227     a=a,
#     228     b=b,
#     229     symmetric_sinkhorn=symmetric_sinkhorn,
#     230     offset_yy=offset_static_b,
#     231     **solve_kwargs
#     232 )
#     233 return out.divergence, out
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/tools/sinkhorn_divergence.py:298, in _sinkhorn_divergence(geometry_xy, geometry_xx, geometry_yy, a, b, symmetric_sinkhorn, offset_yy, **kwargs)
#     295   if implicit_diff is not None:
#     296     kwargs_symmetric["implicit_diff"] = implicit_diff.replace(symmetric=True)
# --> 298 out_xy = linear.solve(geometry_xy, a=a, b=b, **kwargs)
#     299 out_xx = linear.solve(geometry_xx, a=a, b=a, **kwargs_symmetric)
#     300 if geometry_yy is None:
#     301   # Create dummy output, corresponds to scenario where static_b is True.
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/solvers/linear/_solve.py:60, in solve(geom, a, b, tau_a, tau_b, rank, **kwargs)
#      58 else:
#      59   solver = sinkhorn.Sinkhorn(**kwargs)
# ---> 60 return solver(prob)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/solvers/linear/sinkhorn.py:756, in Sinkhorn.__call__(self, ot_prob, init, **kwargs)
#     754 if init is None:
#     755   init = self.initializer(ot_prob, lse_mode=self.lse_mode, **kwargs)
# --> 756 return run(ot_prob, self, init)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/solvers/linear/sinkhorn.py:1013, in run(ot_prob, solver, init)
#    1011 """Run loop of the solver, outputting a state upgraded to an output."""
#    1012 iter_fun = _iterations_implicit if solver.implicit_diff else iterations
# -> 1013 out = iter_fun(ot_prob, solver, init)
#    1014 # Be careful here, the geom and the cost are injected at the end, where it
#    1015 # does not interfere with the implicit differentiation.
#    1016 out = out.set_cost(ot_prob, solver.lse_mode, solver.use_danskin)
#
#     [... skipping hidden 1 frame]
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/custom_derivatives.py:736, in custom_vjp.__call__(self, *args, **kwargs)
#     732 flat_fwd, out_trees = _flatten_fwd(
#     733     fwd_, self.nondiff_argnums, self.symbolic_zeros, debug_fun,
#     734     debug_fwd, in_tree, out_type)
#     735 flat_bwd = _flatten_bwd(bwd, in_tree, in_avals, out_trees)
# --> 736 out_flat = custom_vjp_call_p.bind(flat_fun, flat_fwd, flat_bwd,
#     737                                   *args_flat, out_trees=out_trees,
#     738                                   symbolic_zeros=self.symbolic_zeros)
#     739 _, (out_tree, _, _) = lu.merge_linear_aux(out_type, out_trees)
#     740 return tree_unflatten(out_tree, out_flat)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/custom_derivatives.py:983, in CustomVJPCallPrimitive.bind(self, *args, **params)
#     982 def bind(self, *args, **params):
# --> 983   return self._true_bind(*args, **params)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/custom_derivatives.py:987, in CustomVJPCallPrimitive.bind_with_trace(self, trace, args, params)
#     985 def bind_with_trace(self, trace, args, params):
#     986   fun, fwd, bwd, tracers = args[0], args[1], args[2], args[3:]
# --> 987   return trace.process_custom_vjp_call(self, fun, fwd, bwd, tracers, **params)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:573, in JVPTrace.process_custom_vjp_call(self, prim, fun, fwd, bwd, tracers, out_trees, symbolic_zeros)
#     571 fwd_in = [x for pair in fwd_in for x in pair]   # flatten
#     572 with core.set_current_trace(self.parent_trace):
# --> 573   res_and_primals_out = fwd.call_wrapped(*fwd_in)
#     575 _, res_tree, input_fwds = out_trees()
#     576 num_res_out = res_tree.num_leaves - sum(f is not None for f in input_fwds)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/custom_derivatives.py:837, in _flatten_fwd(f, store, nondiff_argnums, symbolic_zeros, debug_primal, debug_fwd, in_tree, maybe_out_type, *args)
#     835 if config.mutable_array_checks.value:
#     836   _check_for_aliased_refs(f, nondiff_argnums, debug_primal, py_args)
# --> 837 pair_out = f(*py_args)
#     838 if not isinstance(pair_out, (list, tuple)) or len(pair_out) != 2:
#     839   msg = (f"Custom VJP fwd rule {fwd_name} for function {primal_name} "
#     840          "must produce a pair (list or tuple of length two) where the first "
#     841          "element represents the primal output (equal to those of the "
#    (...)    844          "forward pass for use on the backward pass), but "
#     845          f"instead of a pair the fwd rule {fwd_name} produced {pair_out}.")
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/solvers/linear/sinkhorn.py:1063, in _iterations_taped(ot_prob, solver, init)
#    1057 def _iterations_taped(
#    1058     ot_prob: linear_problem.LinearProblem, solver: Sinkhorn,
#    1059     init: Tuple[jnp.ndarray, ...]
#    1060 ) -> Tuple[SinkhornOutput, Tuple[jnp.ndarray, jnp.ndarray,
#    1061                                  linear_problem.LinearProblem, Sinkhorn]]:
#    1062   """Run forward pass of the Sinkhorn algorithm storing side information."""
# -> 1063   state = iterations(ot_prob, solver, init)
#    1064   return state, (state.f, state.g, ot_prob, solver)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/solvers/linear/sinkhorn.py:1054, in iterations(ot_prob, solver, init)
#    1049 state = solver.init_state(ot_prob, init)
#    1050 state = fix_point(
#    1051     cond_fn, body_fn, solver.min_iterations, solver.max_iterations,
#    1052     solver.inner_iterations, const, state
#    1053 )
# -> 1054 return solver.output_from_state(ot_prob, state)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/ott/solvers/linear/sinkhorn.py:976, in Sinkhorn.output_from_state(self, ot_prob, state)
#     964   f, g = state.recenter(f, g, ot_prob=ot_prob)
#     966 # By convention, the algorithm is said to have converged if the algorithm
#     967 # has not nan'ed during iterations (notice some errors might be infinite,
#     968 # this convention is used when the error is not recomputed), and if the
#    (...)    972 # the maximal number of iterations and its last recorded error (at -1
#     973 # position) is lower than the threshold.
#     975 converged = jnp.logical_and(
# --> 976     jnp.logical_not(jnp.any(jnp.isnan(state.errors))), state.errors[-1]
#     977     < self.threshold
#     978 )[0]
#     980 return SinkhornOutput((f, g),
#     981                       errors=state.errors[:, 0],
#     982                       threshold=jnp.array(self.threshold),
#     983                       converged=converged,
#     984                       inner_iterations=self.inner_iterations)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/numpy/reductions.py:677, in any(a, axis, out, keepdims, where)
#     630 @export
#     631 def any(a: ArrayLike, axis: Axis = None, out: None = None,
#     632         keepdims: bool = False, *, where: ArrayLike | None = None) -> Array:
#     633   r"""Test whether any of the array elements along a given axis evaluate to True.
#     634
#     635   JAX implementation of :func:`numpy.any`.
#    (...)    675     Array([[ True, False,  True, False]], dtype=bool)
#     676   """
# --> 677   return _reduce_any(a, axis=_ensure_optional_axes(axis), out=out,
#     678                      keepdims=keepdims, where=where)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/jax/_src/traceback_util.py:178, in api_boundary.<locals>.reraise_with_filtered_traceback(*args, **kwargs)
#     155 def api_boundary(fun: C) -> C:
#     156   '''Wraps ``fun`` to form a boundary for filtering exception tracebacks.
#     157
#     158   When an exception occurs below ``fun``, this appends to it a custom
#    (...)    175   traceback that excludes the frames specific to JAX's implementation.
#     176   '''
# --> 178   @functools.wraps(fun)
#     179   def reraise_with_filtered_traceback(*args, **kwargs):
#     180     __tracebackhide__ = True
#     181     try:
#
# KeyboardInterrupt:
