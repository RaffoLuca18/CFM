# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import data_gen as dg

import torch
import geomloss
import matplotlib.pyplot as plt

# %% [markdown]
# # we continue with the second case

# %%
def langevin_step(samples, theta, eps):

    mu, var = theta[0], theta[1]
    noise = torch.randn_like(samples)
    grad_V = (samples - mu) / var

    return samples - eps * grad_V + torch.sqrt(torch.tensor(2 * eps)) * noise

# %%
def evolve_langevin(samples, theta, eps=1e-2, n_evolution=1000, seed=0):
    
    torch.manual_seed(seed)
    samples_evolved = samples.clone()

    for i in range(n_evolution):
        samples_evolved = langevin_step(samples_evolved, theta, eps)

    return samples_evolved

# %%
sinkhorn_loss = geomloss.SamplesLoss(loss="sinkhorn", p=2, blur=0.05)

def lm_loss(samples, theta):

    evolved_samples = evolve_langevin(samples, theta)
    if samples.ndim == 1:
        samples = samples.unsqueeze(1)
    if evolved_samples.ndim == 1:
        evolved_samples = evolved_samples.unsqueeze(1)

    return sinkhorn_loss(samples, evolved_samples)

# %%
def plot_distributions(samples, evolved):
    samples_np = samples.detach().cpu().numpy().flatten()
    evolved_np = evolved.detach().cpu().numpy().flatten()
    
    plt.figure(figsize=(6, 4))
    plt.hist(samples_np, bins=50, alpha=0.5, label='Original', density=True)
    plt.hist(evolved_np, bins=50, alpha=0.5, label='Evolved', density=True)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
def lm_optimize(samples, n_epochs=300, lr=1e-2):

    theta = torch.tensor([0.0, 1.0], requires_grad=True)

    optimizer = torch.optim.Adam([theta], lr=lr)

    for t in range(n_epochs):
        optimizer.zero_grad()
        loss = lm_loss(samples, theta)
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            theta[1].clamp_(min=1e-3)

        if t % 100 == 0:
            mu_val = theta[0].item()
            var_val = theta[1].item()
            print(f"step {t} | loss = {loss.item():.6f} | mu = {mu_val:.4f} | var = {var_val:.4f}")
            evolved_samples = evolve_langevin(samples, theta)
            plot_distributions(samples, evolved_samples)

    return theta.detach()

# %%
true_mu, true_std = 10.0, 2.0
samples = torch.randn(500) * true_std + true_mu

theta_hat = lm_optimize(samples, n_epochs=5000, lr=0.5)

print(f"final mean:     {theta_hat[0].item():.4f}")
print(f"final variance:  {theta_hat[1].item():.4f}")
# Out:
# step 0 | loss = 50.514465 | mu = 0.5000 | var = 1.5000
# step 100 | loss = 0.137963 | mu = 10.0117 | var = 6.1028
# step 200 | loss = 0.006701 | mu = 10.0092 | var = 3.7128
# step 300 | loss = 0.006796 | mu = 10.0087 | var = 3.7034
# step 400 | loss = 0.006797 | mu = 10.0087 | var = 3.7034
# step 500 | loss = 0.006797 | mu = 10.0087 | var = 3.7034
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 4
#       1 true_mu, true_std = 10.0, 2.0
#       2 samples = torch.randn(500) * true_std + true_mu
# ----> 4 theta_hat = lm_optimize(samples, n_epochs=5000, lr=0.5)
#       6 print(f"final mean:     {theta_hat[0].item():.4f}")
#       7 print(f"final variance:  {theta_hat[1].item():.4f}")
#
# Cell In[18], line 9, in lm_optimize(samples, n_epochs, lr)
#       7 for t in range(n_epochs):
#       8     optimizer.zero_grad()
# ----> 9     loss = lm_loss(samples, theta)
#      10     loss.backward()
#      11     optimizer.step()
#
# Cell In[16], line 11, in lm_loss(samples, theta)
#       8 if evolved_samples.ndim == 1:
#       9     evolved_samples = evolved_samples.unsqueeze(1)
# ---> 11 return sinkhorn_loss(samples, evolved_samples)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/geomloss/samples_loss.py:265, in SamplesLoss.forward(self, *args)
#     262     α, x, β, y = α.unsqueeze(0), x.unsqueeze(0), β.unsqueeze(0), y.unsqueeze(0)
#     264 # Run --------------------------------------------------------------------------------
# --> 265 values = routines[self.loss][backend](
#     266     α,
#     267     x,
#     268     β,
#     269     y,
#     270     p=self.p,
#     271     blur=self.blur,
#     272     reach=self.reach,
#     273     diameter=self.diameter,
#     274     scaling=self.scaling,
#     275     truncate=self.truncate,
#     276     cost=self.cost,
#     277     kernel=self.kernel,
#     278     cluster_scale=self.cluster_scale,
#     279     debias=self.debias,
#     280     potentials=self.potentials,
#     281     labels_x=l_x,
#     282     labels_y=l_y,
#     283     verbose=self.verbose,
#     284 )
#     286 # Make sure that the output has the correct shape ------------------------------------
#     287 if (
#     288     self.potentials
#     289 ):  # Return some dual potentials (= test functions) sampled on the input measures
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/geomloss/sinkhorn_samples.py:196, in sinkhorn_tensorized(a, x, b, y, p, blur, reach, diameter, scaling, cost, debias, potentials, **kwargs)
#     191 diameter, eps, eps_list, rho = scaling_parameters(
#     192     x, y, p, blur, reach, diameter, scaling
#     193 )
#     195 # Use an optimal transport solver to retrieve the dual potentials:
# --> 196 f_aa, g_bb, g_ab, f_ba = sinkhorn_loop(
#     197     softmin_tensorized,
#     198     log_weights(a),
#     199     log_weights(b),
#     200     C_xx,
#     201     C_yy,
#     202     C_xy,
#     203     C_yx,
#     204     eps_list,
#     205     rho,
#     206     debias=debias,
#     207 )
#     209 # Optimal transport cost:
#     210 return sinkhorn_cost(
#     211     eps,
#     212     rho,
#    (...)    221     potentials=potentials,
#     222 )
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/geomloss/sinkhorn_divergence.py:482, in sinkhorn_loop(softmin, a_logs, b_logs, C_xxs, C_yys, C_xys, C_yxs, eps_list, rho, jumps, kernel_truncation, truncate, cost, extrapolate, debias, last_extrapolation)
#     472 damping = dampening(eps, rho)  # eps and damping change across iterations
#     474 # Line 7: "coordinate ascent" on the dual problems -----------------------------
#     475 # N.B.: As discussed in Section 3.3.3 of Jean Feydy's PhD thesis,
#     476 #       we perform "symmetric" instead of "alternate" updates
#    (...)    480 #       Sinkhorn formulas, and update both dual vectors
#     481 #       simultaneously.
# --> 482 ft_ba = damping * softmin(eps, C_xy, b_log + g_ab / eps)  # b -> a
#     483 gt_ab = damping * softmin(eps, C_yx, a_log + f_ba / eps)  # a -> b
#     485 # See Fig. 3.21 in Jean Feydy's PhD thesis to see the importance
#     486 # of debiasing when the target "blur" or "eps**(1/p)" value is larger
#     487 # than the average distance between samples x_i, y_j and their neighbours.
#
# File ~/CFM/cfm_env/lib/python3.13/site-packages/geomloss/sinkhorn_samples.py:72, in softmin_tensorized(eps, C_xy, h_y)
#      34 r"""Soft-C-transform, implemented using dense torch Tensors.
#      35
#      36 This routine implements the (soft-)C-transform
#    (...)     69         by the points :math:`x_i`.
#      70 """
#      71 B = C_xy.shape[0]
# ---> 72 return -eps * (h_y.view(B, 1, -1) - C_xy / eps).logsumexp(2).view(B, -1)
#
# KeyboardInterrupt:
